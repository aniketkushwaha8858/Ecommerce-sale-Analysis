# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
x=pd.read_csv(r"C:\Users\DELL\Downloads\e commerce.csv")
x
# Out:
#      Order_ID Order_Date  Customer_ID   Customer_Name  Gender  Age  \
# 0      500001    00:00.0        43004  Customer_43004  Female   57
# 1      500002    08:45.6        22173  Customer_22173    Male   28
# 2      500003    17:31.2        15193  Customer_15193  Female   63
# 3      500004    26:16.8        42512  Customer_42512    Male   20
# 4      500005    35:02.4        17814  Customer_17814    Male   31
# ..        ...        ...          ...             ...     ...  ...
# 994    500995    07:30.8        29144  Customer_29144  Female   36
# 995    500996    16:16.4        28695  Customer_28695    Male   23
# 996    500997    25:02.0        36561  Customer_36561    Male   64
# 997    500998    33:47.6        33603  Customer_33603  Female   50
# 998    500999    42:33.2        36715  Customer_36715    Male   37
#
#            Category     Product  Quantity  Price      Payment_Mode  \
# 0           Fashion  Headphones         3  25651        Debit Card
# ...

# %%
x.head()
# Out:
#    Order_ID Order_Date  Customer_ID   Customer_Name  Gender  Age  \
# 0    500001    00:00.0        43004  Customer_43004  Female   57
# 1    500002    08:45.6        22173  Customer_22173    Male   28
# 2    500003    17:31.2        15193  Customer_15193  Female   63
# 3    500004    26:16.8        42512  Customer_42512    Male   20
# 4    500005    35:02.4        17814  Customer_17814    Male   31
#
#          Category     Product  Quantity  Price Payment_Mode Order_Status  \
# 0         Fashion  Headphones         3  25651   Debit Card    Delivered
# 1     Electronics       Shoes         1  32513   Debit Card    Delivered
# 2          Sports    Lipstick         1  37657   Debit Card    Cancelled
# 3  Home & Kitchen     T-Shirt         1   9642          UPI    Cancelled
# 4         Fashion       Mixer         2  41016          UPI    Cancelled
#
#         City  Total_Amount
# 0       Pune         76953
# 1  Bangalore         32513
# 2  Hyderabad         37657
# ...

# %%
x.tail()
# Out:
#      Order_ID Order_Date  Customer_ID   Customer_Name  Gender  Age  \
# 994    500995    07:30.8        29144  Customer_29144  Female   36
# 995    500996    16:16.4        28695  Customer_28695    Male   23
# 996    500997    25:02.0        36561  Customer_36561    Male   64
# 997    500998    33:47.6        33603  Customer_33603  Female   50
# 998    500999    42:33.2        36715  Customer_36715    Male   37
#
#            Category     Product  Quantity  Price      Payment_Mode  \
# 994     Electronics  Headphones         1   4261  Cash on Delivery
# 995          Beauty       Watch         4   7109               UPI
# 996  Home & Kitchen    Lipstick         1  57760        Debit Card
# 997  Home & Kitchen      Laptop         2  20465        Debit Card
# 998          Sports  Headphones         1  60163               UPI
#
#     Order_Status       City  Total_Amount
# 994    Delivered      Noida          4261
# 995    Cancelled  Bangalore         28436
# ...

# %%
x.describe()
# Out:
#             Order_ID   Customer_ID         Age    Quantity         Price  \
# count     999.000000    999.000000  999.000000  999.000000    999.000000
# mean   500500.000000  30432.775776   40.825826    2.496496  35473.404404
# std       288.530761  11505.870533   13.744654    1.096422  20493.260396
# min    500001.000000  10016.000000   18.000000    1.000000    348.000000
# 25%    500250.500000  20986.000000   29.000000    2.000000  17410.500000
# 50%    500500.000000  30486.000000   41.000000    2.000000  35491.000000
# 75%    500749.500000  40014.000000   53.000000    3.000000  53914.000000
# max    500999.000000  49965.000000   64.000000    4.000000  69955.000000
#
#         Total_Amount
# count     999.000000
# mean    89680.140140
# std     69734.747752
# min       348.000000
# 25%     33271.000000
# 50%     68763.000000
# 75%    132683.000000
# max    278092.000000

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order_ID       999 non-null    int64
#  1   Order_Date     999 non-null    object
#  2   Customer_ID    999 non-null    int64
#  3   Customer_Name  999 non-null    object
#  4   Gender         999 non-null    object
#  5   Age            999 non-null    int64
#  6   Category       999 non-null    object
#  7   Product        999 non-null    object
#  8   Quantity       999 non-null    int64
#  9   Price          999 non-null    int64
#  10  Payment_Mode   999 non-null    object
#  11  Order_Status   999 non-null    object
#  12  City           999 non-null    object
#  13  Total_Amount   999 non-null    int64
# dtypes: int64(6), object(8)
# memory usage: 109.4+ KB

# %%
x["Gender"]
# Out:
# 0      Female
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 994    Female
# 995      Male
# 996      Male
# 997    Female
# 998      Male
# Name: Gender, Length: 999, dtype: object

# %%
x["Gender"]=x["Gender"].map({'Female':0,'Male':1})
x["Gender"]
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      1
#       ..
# 994    0
# 995    1
# 996    1
# 997    0
# 998    1
# Name: Gender, Length: 999, dtype: int64

# %%
x
# Out:
#      Order_ID Order_Date  Customer_ID   Customer_Name  Gender  Age  \
# 0      500001    00:00.0        43004  Customer_43004       0   57
# 1      500002    08:45.6        22173  Customer_22173       1   28
# 2      500003    17:31.2        15193  Customer_15193       0   63
# 3      500004    26:16.8        42512  Customer_42512       1   20
# 4      500005    35:02.4        17814  Customer_17814       1   31
# ..        ...        ...          ...             ...     ...  ...
# 994    500995    07:30.8        29144  Customer_29144       0   36
# 995    500996    16:16.4        28695  Customer_28695       1   23
# 996    500997    25:02.0        36561  Customer_36561       1   64
# 997    500998    33:47.6        33603  Customer_33603       0   50
# 998    500999    42:33.2        36715  Customer_36715       1   37
#
#            Category     Product  Quantity  Price      Payment_Mode  \
# 0           Fashion  Headphones         3  25651        Debit Card
# ...

# %%
x["Age"][x["Age"]<45]
# Out:
# 1      28
# 3      20
# 4      31
# 5      37
# 6      30
#        ..
# 992    29
# 993    39
# 994    36
# 995    23
# 998    37
# Name: Age, Length: 570, dtype: int64

# %%
x.count()
# Out:
# Order_ID         999
# Order_Date       999
# Customer_ID      999
# Customer_Name    999
# Gender           999
# Age              999
# Category         999
# Product          999
# Quantity         999
# Price            999
# Payment_Mode     999
# Order_Status     999
# City             999
# Total_Amount     999
# dtype: int64

# %%
x.max()
# Out:
# Order_ID                 500999
# Order_Date              59:56.6
# Customer_ID               49965
# Customer_Name    Customer_49965
# Gender                        1
# Age                       False
# Category                 Sports
# Product                   Watch
# Quantity                      4
# Price                     69955
# Payment_Mode                UPI
# Order_Status           Returned
# City                       Pune
# Total_Amount             278092
# dtype: object

# %%
x.min()
# Out:
# Order_ID                   500001
# Order_Date                00:00.0
# Customer_ID                 10016
# Customer_Name      Customer_10016
# Gender                          0
# Age                         False
# Category                   Beauty
# Product                Headphones
# Quantity                        1
# Price                         348
# Payment_Mode     Cash on Delivery
# Order_Status            Cancelled
# City                    Bangalore
# Total_Amount                  348
# dtype: object

# %%
x=x.drop_duplicates()

# %%
x
# Out:
#      Order_ID Order_Date  Customer_ID   Customer_Name  Gender  Age  \
# 0      500001    00:00.0        43004  Customer_43004       0   57
# 1      500002    08:45.6        22173  Customer_22173       1   28
# 2      500003    17:31.2        15193  Customer_15193       0   63
# 3      500004    26:16.8        42512  Customer_42512       1   20
# 4      500005    35:02.4        17814  Customer_17814       1   31
# ..        ...        ...          ...             ...     ...  ...
# 994    500995    07:30.8        29144  Customer_29144       0   36
# 995    500996    16:16.4        28695  Customer_28695       1   23
# 996    500997    25:02.0        36561  Customer_36561       1   64
# 997    500998    33:47.6        33603  Customer_33603       0   50
# 998    500999    42:33.2        36715  Customer_36715       1   37
#
#            Category     Product  Quantity  Price      Payment_Mode  \
# 0           Fashion  Headphones         3  25651        Debit Card
# ...

# %%
x["Age"].count()
# Out:
# np.int64(999)

# %%
x.isnull().sum()
# Out:
# Order_ID         0
# Order_Date       0
# Customer_ID      0
# Customer_Name    0
# Gender           0
# Age              0
# Category         0
# Product          0
# Quantity         0
# Price            0
# Payment_Mode     0
# Order_Status     0
# City             0
# Total_Amount     0
# dtype: int64

# %%
x
# Out:
#      Order_ID Order_Date  Customer_ID   Customer_Name  Gender  Age  \
# 0      500001    00:00.0        43004  Customer_43004  Female   57
# 1      500002    08:45.6        22173  Customer_22173    Male   28
# 2      500003    17:31.2        15193  Customer_15193  Female   63
# 3      500004    26:16.8        42512  Customer_42512    Male   20
# 4      500005    35:02.4        17814  Customer_17814    Male   31
# ..        ...        ...          ...             ...     ...  ...
# 994    500995    07:30.8        29144  Customer_29144  Female   36
# 995    500996    16:16.4        28695  Customer_28695    Male   23
# 996    500997    25:02.0        36561  Customer_36561    Male   64
# 997    500998    33:47.6        33603  Customer_33603  Female   50
# 998    500999    42:33.2        36715  Customer_36715    Male   37
#
#            Category     Product  Quantity  Price      Payment_Mode  \
# 0           Fashion  Headphones         3  25651        Debit Card
# ...

# %%
x.boxplot()
# Out:
# <Axes: >

# %%
x.plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
x
# Out:
#      Order_ID Order_Date  Customer_ID   Customer_Name  Gender  Age  \
# 0      500001    00:00.0        43004  Customer_43004  Female   57
# 1      500002    08:45.6        22173  Customer_22173    Male   28
# 2      500003    17:31.2        15193  Customer_15193  Female   63
# 3      500004    26:16.8        42512  Customer_42512    Male   20
# 4      500005    35:02.4        17814  Customer_17814    Male   31
# ..        ...        ...          ...             ...     ...  ...
# 994    500995    07:30.8        29144  Customer_29144  Female   36
# 995    500996    16:16.4        28695  Customer_28695    Male   23
# 996    500997    25:02.0        36561  Customer_36561    Male   64
# 997    500998    33:47.6        33603  Customer_33603  Female   50
# 998    500999    42:33.2        36715  Customer_36715    Male   37
#
#            Category     Product  Quantity  Price      Payment_Mode  \
# 0           Fashion  Headphones         3  25651        Debit Card
# ...

# %%
categorygroupby=x.groupby('Category')['Total_Amount'].sum()

# %%
categorygroupby
# Out:
# Category
# Beauty            17815036
# Electronics       17643980
# Fashion           19486472
# Home & Kitchen    16652792
# Sports            17992180
# Name: Total_Amount, dtype: int64

# %%
productby=x.groupby('Product')['Total_Amount'].sum()

# %%
productby
# Out:
# Product
# Headphones    12389293
# Laptop        11772336
# Lipstick      11785429
# Mixer         12095042
# Mobile        12240295
# Shoes          8971687
# T-Shirt        9299539
# Watch         11036839
# Name: Total_Amount, dtype: int64

# %%
cityby=x.groupby('City')['Total_Amount'].sum()

# %%
cityby
# Out:
# City
# Bangalore    11015941
# Chennai      10083285
# Delhi        11602280
# Gurgaon      11637018
# Hyderabad    11974888
# Mumbai       13233104
# Noida         9142457
# Pune         10901487
# Name: Total_Amount, dtype: int64

# %%
city=x.groupby('City')['Gender'].count()

# %%
city
# Out:
# City
# Bangalore    126
# Chennai      120
# Delhi        122
# Gurgaon      128
# Hyderabad    125
# Mumbai       147
# Noida        114
# Pune         117
# Name: Gender, dtype: int64

# %%
cityby.plot(kind='bar')
plt.title("city wise sales")
plt.xlabel("City")
plt.ylabel("Total sale")
plt.show()

# %%
productby.plot(kind='pie')
plt.title("product wise sales")
plt.xlabel("Product")
plt.ylabel("Total sale")
plt.show()

# %%
productby.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
productby.plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
categorygroupby.plot(kind="pie")
# Out:
# <Axes: ylabel='Total_Amount'>

# %%
x["Gender"]=x["Gender"].map({'Female':0,'Male':1})
x["Gender"]
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      1
#       ..
# 994    0
# 995    1
# 996    1
# 997    0
# 998    1
# Name: Gender, Length: 999, dtype: int64

# %%
x
# Out:
#      Order_ID Order_Date  Customer_ID   Customer_Name  Gender  Age  \
# 0      500001    00:00.0        43004  Customer_43004       0   57
# 1      500002    08:45.6        22173  Customer_22173       1   28
# 2      500003    17:31.2        15193  Customer_15193       0   63
# 3      500004    26:16.8        42512  Customer_42512       1   20
# 4      500005    35:02.4        17814  Customer_17814       1   31
# ..        ...        ...          ...             ...     ...  ...
# 994    500995    07:30.8        29144  Customer_29144       0   36
# 995    500996    16:16.4        28695  Customer_28695       1   23
# 996    500997    25:02.0        36561  Customer_36561       1   64
# 997    500998    33:47.6        33603  Customer_33603       0   50
# 998    500999    42:33.2        36715  Customer_36715       1   37
#
#            Category     Product  Quantity  Price      Payment_Mode  \
# 0           Fashion  Headphones         3  25651        Debit Card
# ...

# %%
x["Gender"]=x["Gender"]==0

# %%
x["Gender"].sum()
# Out:
# np.int64(0)
